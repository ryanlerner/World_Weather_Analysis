# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 760

# %%
# Import your Requests Library and the weather_api_key.
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
        
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
        
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kadhan
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | vallenar
# Processing Record 5 of Set 1 | sao joao da barra
# Processing Record 6 of Set 1 | copiapo
# Processing Record 7 of Set 1 | tahta
# Processing Record 8 of Set 1 | meulaboh
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | vila velha
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | coquimbo
# Processing Record 14 of Set 1 | cravo norte
# Processing Record 15 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 1 | matane
# Processing Record 17 of Set 1 | souillac
# Processing Record 18 of Set 1 | burica
# City not found. Skipping...
# Processing Record 19 of Set 1 | saldanha
# Processing Record 20 of Set 1 | necochea
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | kabo
# Processing Record 23 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 1 | ati
# Processing Record 25 of Set 1 | floridia
# Processing Record 26 of Set 1 | pontes e lacerda
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | asfi
# Processing Record 29 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 1 | dingle
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 1 | kalabo
# Processing Record 33 of Set 1 | kudahuvadhoo
# Processing Record 34 of Set 1 | conceicao do araguaia
# Processing Record 35 of Set 1 | boden
# Processing Record 36 of Set 1 | bathsheba
# Processing Record 37 of Set 1 | chuy
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | longyearbyen
# Processing Record 40 of Set 1 | natal
# Processing Record 41 of Set 1 | riyadh
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | clayton
# Processing Record 46 of Set 1 | klaksvik
# Processing Record 47 of Set 1 | veraval
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | vestmannaeyjar
# Processing Record 1 of Set 2 | zheshart
# Processing Record 2 of Set 2 | bengkulu
# Processing Record 3 of Set 2 | joshimath
# Processing Record 4 of Set 2 | uaua
# Processing Record 5 of Set 2 | aviemore
# Processing Record 6 of Set 2 | mangla
# Processing Record 7 of Set 2 | mizpe ramon
# City not found. Skipping...
# Processing Record 8 of Set 2 | sitapur
# Processing Record 9 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 2 | cabo rojo
# Processing Record 11 of Set 2 | marica
# Processing Record 12 of Set 2 | tshikapa
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | caravelas
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | san cristobal
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | nosy varika
# Processing Record 21 of Set 2 | grand gaube
# Processing Record 22 of Set 2 | lilongwe
# Processing Record 23 of Set 2 | qandahar
# City not found. Skipping...
# Processing Record 24 of Set 2 | djambala
# Processing Record 25 of Set 2 | moose factory
# Processing Record 26 of Set 2 | suoyarvi
# Processing Record 27 of Set 2 | qaqortoq
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | labytnangi
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | laguna
# Processing Record 32 of Set 2 | rawson
# Processing Record 33 of Set 2 | cervo
# Processing Record 34 of Set 2 | mahibadhoo
# Processing Record 35 of Set 2 | husavik
# Processing Record 36 of Set 2 | palmeira
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | puerto del rosario
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 2 | uige
# Processing Record 44 of Set 2 | maceio
# Processing Record 45 of Set 2 | leirvik
# Processing Record 46 of Set 2 | elk
# Processing Record 47 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 2 | bambous virieux
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | dongobesh
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 3 | koltubanovskiy
# Processing Record 5 of Set 3 | cidreira
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | hofn
# Processing Record 8 of Set 3 | jijiga
# Processing Record 9 of Set 3 | chokwe
# Processing Record 10 of Set 3 | narsaq
# Processing Record 11 of Set 3 | kedrovyy
# Processing Record 12 of Set 3 | djougou
# Processing Record 13 of Set 3 | booue
# Processing Record 14 of Set 3 | kutum
# Processing Record 15 of Set 3 | coihaique
# Processing Record 16 of Set 3 | qandala
# Processing Record 17 of Set 3 | neyshabur
# Processing Record 18 of Set 3 | tsogni
# Processing Record 19 of Set 3 | ulagan
# Processing Record 20 of Set 3 | kabare
# Processing Record 21 of Set 3 | fereydunshahr
# Processing Record 22 of Set 3 | praia da vitoria
# Processing Record 23 of Set 3 | faya
# Processing Record 24 of Set 3 | kirkwall
# Processing Record 25 of Set 3 | mpika
# Processing Record 26 of Set 3 | dalbandin
# Processing Record 27 of Set 3 | nanortalik
# Processing Record 28 of Set 3 | inhambane
# Processing Record 29 of Set 3 | uyuni
# Processing Record 30 of Set 3 | knysna
# Processing Record 31 of Set 3 | bo
# City not found. Skipping...
# Processing Record 32 of Set 3 | saint-joseph
# Processing Record 33 of Set 3 | annau
# Processing Record 34 of Set 3 | bud
# Processing Record 35 of Set 3 | asekeyevo
# Processing Record 36 of Set 3 | ciudad bolivar
# Processing Record 37 of Set 3 | lodwar
# Processing Record 38 of Set 3 | yenagoa
# Processing Record 39 of Set 3 | laje
# Processing Record 40 of Set 3 | dwarka
# Processing Record 41 of Set 3 | touros
# Processing Record 42 of Set 3 | santa maria
# Processing Record 43 of Set 3 | ilulissat
# Processing Record 44 of Set 3 | omboue
# Processing Record 45 of Set 3 | belmonte
# Processing Record 46 of Set 3 | pasni
# Processing Record 47 of Set 3 | rosa zarate
# Processing Record 48 of Set 3 | kruisfontein
# Processing Record 49 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 3 | nouadhibou
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | umm lajj
# Processing Record 3 of Set 4 | victoria
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | samfya
# Processing Record 6 of Set 4 | maragogi
# Processing Record 7 of Set 4 | imbituba
# Processing Record 8 of Set 4 | gilgit
# Processing Record 9 of Set 4 | hithadhoo
# Processing Record 10 of Set 4 | madaoua
# Processing Record 11 of Set 4 | lasa
# Processing Record 12 of Set 4 | polyarnyy
# Processing Record 13 of Set 4 | port blair
# Processing Record 14 of Set 4 | terralba
# Processing Record 15 of Set 4 | garowe
# Processing Record 16 of Set 4 | bubaque
# Processing Record 17 of Set 4 | sinnamary
# Processing Record 18 of Set 4 | westport
# Processing Record 19 of Set 4 | marquette
# Processing Record 20 of Set 4 | torbay
# Processing Record 21 of Set 4 | dustlik
# Processing Record 22 of Set 4 | maniitsoq
# Processing Record 23 of Set 4 | candelaria
# Processing Record 24 of Set 4 | at-bashi
# Processing Record 25 of Set 4 | kargapolye
# City not found. Skipping...
# Processing Record 26 of Set 4 | salalah
# Processing Record 27 of Set 4 | hermanus
# Processing Record 28 of Set 4 | antigonish
# Processing Record 29 of Set 4 | saint-pierre
# Processing Record 30 of Set 4 | kavaratti
# Processing Record 31 of Set 4 | tabou
# Processing Record 32 of Set 4 | umm kaddadah
# Processing Record 33 of Set 4 | berlevag
# Processing Record 34 of Set 4 | acri
# Processing Record 35 of Set 4 | pangnirtung
# Processing Record 36 of Set 4 | ayagoz
# Processing Record 37 of Set 4 | damaturu
# Processing Record 38 of Set 4 | carutapera
# Processing Record 39 of Set 4 | rincon
# Processing Record 40 of Set 4 | sovetsk
# Processing Record 41 of Set 4 | antofagasta
# Processing Record 42 of Set 4 | boromo
# Processing Record 43 of Set 4 | hambantota
# Processing Record 44 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 45 of Set 4 | sao filipe
# Processing Record 46 of Set 4 | vilhena
# Processing Record 47 of Set 4 | roald
# Processing Record 48 of Set 4 | capitao poco
# Processing Record 49 of Set 4 | agva
# City not found. Skipping...
# Processing Record 50 of Set 4 | shambu
# Processing Record 1 of Set 5 | ilave
# Processing Record 2 of Set 5 | san-pedro
# Processing Record 3 of Set 5 | clearwater
# Processing Record 4 of Set 5 | gat
# Processing Record 5 of Set 5 | pokaran
# Processing Record 6 of Set 5 | valdivia
# Processing Record 7 of Set 5 | porto belo
# Processing Record 8 of Set 5 | lejanias
# Processing Record 9 of Set 5 | siavonga
# Processing Record 10 of Set 5 | yar-sale
# Processing Record 11 of Set 5 | gwadar
# Processing Record 12 of Set 5 | nuuk
# Processing Record 13 of Set 5 | kaduy
# Processing Record 14 of Set 5 | lucea
# Processing Record 15 of Set 5 | zaysan
# Processing Record 16 of Set 5 | mwinilunga
# Processing Record 17 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 5 | eucaliptus
# Processing Record 19 of Set 5 | haverfordwest
# Processing Record 20 of Set 5 | kalangala
# Processing Record 21 of Set 5 | bordighera
# Processing Record 22 of Set 5 | zheleznodorozhnyy
# Processing Record 23 of Set 5 | gravina in puglia
# Processing Record 24 of Set 5 | bereda
# Processing Record 25 of Set 5 | livingstonia
# Processing Record 26 of Set 5 | kirkenes
# Processing Record 27 of Set 5 | kumbhraj
# Processing Record 28 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 29 of Set 5 | temyasovo
# Processing Record 30 of Set 5 | harper
# Processing Record 31 of Set 5 | groningen
# Processing Record 32 of Set 5 | soanierana ivongo
# Processing Record 33 of Set 5 | santa vitoria do palmar
# Processing Record 34 of Set 5 | clyde river
# Processing Record 35 of Set 5 | abu dhabi
# Processing Record 36 of Set 5 | bartica
# Processing Record 37 of Set 5 | bembereke
# Processing Record 38 of Set 5 | carnarvon
# Processing Record 39 of Set 5 | alice town
# Processing Record 40 of Set 5 | neftcala
# Processing Record 41 of Set 5 | obo
# Processing Record 42 of Set 5 | sidi qasim
# City not found. Skipping...
# Processing Record 43 of Set 5 | walvis bay
# Processing Record 44 of Set 5 | rodrigues alves
# Processing Record 45 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 46 of Set 5 | kharitonovo
# Processing Record 47 of Set 5 | sao luis de montes belos
# Processing Record 48 of Set 5 | yining
# Processing Record 49 of Set 5 | cap-aux-meules
# Processing Record 50 of Set 5 | tessalit
# Processing Record 1 of Set 6 | salacgriva
# Processing Record 2 of Set 6 | brae
# Processing Record 3 of Set 6 | bonito
# Processing Record 4 of Set 6 | mikhaylovka
# Processing Record 5 of Set 6 | codrington
# Processing Record 6 of Set 6 | baldeogarh
# Processing Record 7 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 8 of Set 6 | sainte-marie
# Processing Record 9 of Set 6 | sisimiut
# Processing Record 10 of Set 6 | jumla
# Processing Record 11 of Set 6 | comodoro rivadavia
# Processing Record 12 of Set 6 | salinas
# Processing Record 13 of Set 6 | ukrayinka
# Processing Record 14 of Set 6 | esna
# Processing Record 15 of Set 6 | havre-saint-pierre
# Processing Record 16 of Set 6 | quatre cocos
# Processing Record 17 of Set 6 | bilaspur
# Processing Record 18 of Set 6 | bilma
# Processing Record 19 of Set 6 | pampierstad
# Processing Record 20 of Set 6 | ivangorod
# Processing Record 21 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 6 | jurado
# Processing Record 23 of Set 6 | pokhara
# Processing Record 24 of Set 6 | bouca
# Processing Record 25 of Set 6 | oktyabrskiy
# Processing Record 26 of Set 6 | abha
# Processing Record 27 of Set 6 | laukaa
# Processing Record 28 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 6 | vilani
# Processing Record 30 of Set 6 | los llanos de aridane
# Processing Record 31 of Set 6 | marawi
# Processing Record 32 of Set 6 | honningsvag
# Processing Record 33 of Set 6 | buy
# Processing Record 34 of Set 6 | saint-augustin
# Processing Record 35 of Set 6 | mezen
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 | alakurtti
# Processing Record 38 of Set 6 | atar
# Processing Record 39 of Set 6 | coruripe
# Processing Record 40 of Set 6 | ostrovnoy
# Processing Record 41 of Set 6 | sheopur
# Processing Record 42 of Set 6 | sambava
# Processing Record 43 of Set 6 | padang
# Processing Record 44 of Set 6 | olonets
# Processing Record 45 of Set 6 | aspindza
# Processing Record 46 of Set 6 | beira
# Processing Record 47 of Set 6 | choya
# Processing Record 48 of Set 6 | motala
# Processing Record 49 of Set 6 | sokolo
# Processing Record 50 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 1 of Set 7 | velyka pysarivka
# Processing Record 2 of Set 7 | hobyo
# Processing Record 3 of Set 7 | iquitos
# Processing Record 4 of Set 7 | adrar
# Processing Record 5 of Set 7 | goderich
# Processing Record 6 of Set 7 | bom jesus da lapa
# Processing Record 7 of Set 7 | high rock
# Processing Record 8 of Set 7 | tres arroyos
# Processing Record 9 of Set 7 | north myrtle beach
# Processing Record 10 of Set 7 | cap malheureux
# Processing Record 11 of Set 7 | taoudenni
# Processing Record 12 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 13 of Set 7 | shache
# Processing Record 14 of Set 7 | dimbokro
# Processing Record 15 of Set 7 | talnakh
# Processing Record 16 of Set 7 | aquiraz
# Processing Record 17 of Set 7 | tank
# Processing Record 18 of Set 7 | orocue
# Processing Record 19 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 7 | menzelinsk
# Processing Record 21 of Set 7 | rocha
# Processing Record 22 of Set 7 | itarema
# Processing Record 23 of Set 7 | sinop
# Processing Record 24 of Set 7 | koulamoutou
# Processing Record 25 of Set 7 | novomikhaylovskiy
# Processing Record 26 of Set 7 | lagoa
# Processing Record 27 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 28 of Set 7 | geraldton
# Processing Record 29 of Set 7 | vardo
# Processing Record 30 of Set 7 | barra patuca
# Processing Record 31 of Set 7 | matagami
# Processing Record 32 of Set 7 | phalaborwa
# Processing Record 33 of Set 7 | namyslow
# Processing Record 34 of Set 7 | sao desiderio
# Processing Record 35 of Set 7 | aviles
# Processing Record 36 of Set 7 | alghero
# Processing Record 37 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 38 of Set 7 | ilo
# Processing Record 39 of Set 7 | kimberley
# Processing Record 40 of Set 7 | pires do rio
# Processing Record 41 of Set 7 | boende
# Processing Record 42 of Set 7 | iqaluit
# Processing Record 43 of Set 7 | reyes
# Processing Record 44 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 45 of Set 7 | ascension
# Processing Record 46 of Set 7 | oussouye
# Processing Record 47 of Set 7 | mutis
# Processing Record 48 of Set 7 | plesetsk
# Processing Record 49 of Set 7 | muros
# Processing Record 50 of Set 7 | margate
# Processing Record 1 of Set 8 | tiznit
# Processing Record 2 of Set 8 | yarmouth
# Processing Record 3 of Set 8 | sioux lookout
# Processing Record 4 of Set 8 | bonavista
# Processing Record 5 of Set 8 | hamilton
# Processing Record 6 of Set 8 | marzuq
# Processing Record 7 of Set 8 | isilkul
# Processing Record 8 of Set 8 | new glasgow
# Processing Record 9 of Set 8 | harindanga
# Processing Record 10 of Set 8 | nyimba
# Processing Record 11 of Set 8 | pudozh
# Processing Record 12 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 13 of Set 8 | uzunovo
# Processing Record 14 of Set 8 | bachaquero
# Processing Record 15 of Set 8 | chicama
# Processing Record 16 of Set 8 | sassandra
# Processing Record 17 of Set 8 | sesheke
# Processing Record 18 of Set 8 | impfondo
# Processing Record 19 of Set 8 | pascagoula
# Processing Record 20 of Set 8 | santa fe
# Processing Record 21 of Set 8 | aurangabad
# Processing Record 22 of Set 8 | port-cartier
# Processing Record 23 of Set 8 | henties bay
# Processing Record 24 of Set 8 | soyo
# Processing Record 25 of Set 8 | trelew
# Processing Record 26 of Set 8 | san pedro
# Processing Record 27 of Set 8 | santa rosa
# Processing Record 28 of Set 8 | marfino
# Processing Record 29 of Set 8 | chake chake
# Processing Record 30 of Set 8 | paoua
# Processing Record 31 of Set 8 | wampusirpi
# City not found. Skipping...
# Processing Record 32 of Set 8 | brosteni
# Processing Record 33 of Set 8 | ikalamavony
# Processing Record 34 of Set 8 | banikoara
# Processing Record 35 of Set 8 | richards bay
# Processing Record 36 of Set 8 | barentu
# Processing Record 37 of Set 8 | harboore
# Processing Record 38 of Set 8 | nioro
# Processing Record 39 of Set 8 | porto novo
# Processing Record 40 of Set 8 | tukrah
# Processing Record 41 of Set 8 | coari
# Processing Record 42 of Set 8 | veshenskaya
# Processing Record 43 of Set 8 | bonthe
# Processing Record 44 of Set 8 | cascais
# Processing Record 45 of Set 8 | colares
# Processing Record 46 of Set 8 | alexandria
# Processing Record 47 of Set 8 | marsh harbour
# Processing Record 48 of Set 8 | mogadishu
# Processing Record 49 of Set 8 | iskateley
# Processing Record 50 of Set 8 | cockburn town
# Processing Record 1 of Set 9 | saint-louis
# Processing Record 2 of Set 9 | micomeseng
# Processing Record 3 of Set 9 | orangeburg
# Processing Record 4 of Set 9 | wundanyi
# Processing Record 5 of Set 9 | severnyy
# Processing Record 6 of Set 9 | okha
# Processing Record 7 of Set 9 | moreira sales
# Processing Record 8 of Set 9 | mwembe
# Processing Record 9 of Set 9 | corozal
# Processing Record 10 of Set 9 | gezing
# Processing Record 11 of Set 9 | bardiyah
# Processing Record 12 of Set 9 | riachao das neves
# Processing Record 13 of Set 9 | pisco
# Processing Record 14 of Set 9 | arlit
# Processing Record 15 of Set 9 | springbok
# Processing Record 16 of Set 9 | saurimo
# Processing Record 17 of Set 9 | havoysund
# Processing Record 18 of Set 9 | luderitz
# Processing Record 19 of Set 9 | camacha
# Processing Record 20 of Set 9 | agvali
# Processing Record 21 of Set 9 | meaford
# Processing Record 22 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 23 of Set 9 | iroquois falls
# Processing Record 24 of Set 9 | ponnani
# Processing Record 25 of Set 9 | malinovoye ozero
# Processing Record 26 of Set 9 | takoradi
# Processing Record 27 of Set 9 | caibarien
# Processing Record 28 of Set 9 | krasnoselkup
# Processing Record 29 of Set 9 | ganganagar
# Processing Record 30 of Set 9 | port-gentil
# Processing Record 31 of Set 9 | kogon
# Processing Record 32 of Set 9 | aswan
# Processing Record 33 of Set 9 | antalaha
# Processing Record 34 of Set 9 | kristiinankaupunki
# Processing Record 35 of Set 9 | san antonio
# Processing Record 36 of Set 9 | derzhavinsk
# Processing Record 37 of Set 9 | igrim
# Processing Record 38 of Set 9 | kikwit
# Processing Record 39 of Set 9 | tvoroyri
# Processing Record 40 of Set 9 | luxeuil-les-bains
# Processing Record 41 of Set 9 | boralday
# Processing Record 42 of Set 9 | hukuntsi
# Processing Record 43 of Set 9 | qarqin
# Processing Record 44 of Set 9 | grand-lahou
# Processing Record 45 of Set 9 | catalina
# Processing Record 46 of Set 9 | trofors
# Processing Record 47 of Set 9 | haukipudas
# Processing Record 48 of Set 9 | panama city
# Processing Record 49 of Set 9 | waddan
# Processing Record 50 of Set 9 | menongue
# Processing Record 1 of Set 10 | xudat
# Processing Record 2 of Set 10 | ereymentau
# Processing Record 3 of Set 10 | gayeri
# Processing Record 4 of Set 10 | vlakhopoulon
# Processing Record 5 of Set 10 | axim
# Processing Record 6 of Set 10 | montilla
# Processing Record 7 of Set 10 | puerto ayacucho
# Processing Record 8 of Set 10 | karpathos
# Processing Record 9 of Set 10 | kadoma
# Processing Record 10 of Set 10 | ierapetra
# Processing Record 11 of Set 10 | sakakah
# Processing Record 12 of Set 10 | knyaginino
# Processing Record 13 of Set 10 | pasinler
# Processing Record 14 of Set 10 | bezhetsk
# Processing Record 15 of Set 10 | grindavik
# Processing Record 16 of Set 10 | olafsvik
# Processing Record 17 of Set 10 | kalmunai
# Processing Record 18 of Set 10 | kula
# Processing Record 19 of Set 10 | sandwick
# Processing Record 20 of Set 10 | skjold
# Processing Record 21 of Set 10 | xai-xai
# Processing Record 22 of Set 10 | ambilobe
# Processing Record 23 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 10 | oktyabrskoye
# Processing Record 25 of Set 10 | salinopolis
# Processing Record 26 of Set 10 | san luis
# Processing Record 27 of Set 10 | bereznehuvate
# Processing Record 28 of Set 10 | cayenne
# Processing Record 29 of Set 10 | maneromango
# Processing Record 30 of Set 10 | damietta
# Processing Record 31 of Set 10 | nkowakowa
# Processing Record 32 of Set 10 | ilhabela
# Processing Record 33 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 10 | pirapora
# Processing Record 35 of Set 10 | sharjah
# Processing Record 36 of Set 10 | urumqi
# Processing Record 37 of Set 10 | dzaoudzi
# Processing Record 38 of Set 10 | ballina
# Processing Record 39 of Set 10 | lukovetskiy
# Processing Record 40 of Set 10 | marystown
# Processing Record 41 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 42 of Set 10 | yelan-kolenovskiy
# Processing Record 43 of Set 10 | vuktyl
# Processing Record 44 of Set 10 | tolbazy
# Processing Record 45 of Set 10 | koulikoro
# Processing Record 46 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 10 | paranaiba
# Processing Record 48 of Set 10 | hwange
# Processing Record 49 of Set 10 | mazamari
# Processing Record 50 of Set 10 | trogir
# Processing Record 1 of Set 11 | puerto cabezas
# Processing Record 2 of Set 11 | mineros
# Processing Record 3 of Set 11 | barceloneta
# Processing Record 4 of Set 11 | chapais
# Processing Record 5 of Set 11 | kuruman
# Processing Record 6 of Set 11 | kilmallock
# Processing Record 7 of Set 11 | ancud
# Processing Record 8 of Set 11 | rio branco
# Processing Record 9 of Set 11 | aasiaat
# Processing Record 10 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 11 | ratnagiri
# Processing Record 12 of Set 11 | krizevci
# Processing Record 13 of Set 11 | maniwaki
# Processing Record 14 of Set 11 | riviere-du-loup
# Processing Record 15 of Set 11 | la rioja
# Processing Record 16 of Set 11 | kindu
# Processing Record 17 of Set 11 | hirna
# Processing Record 18 of Set 11 | bandarbeyla
# Processing Record 19 of Set 11 | la macarena
# Processing Record 20 of Set 11 | tacna
# Processing Record 21 of Set 11 | ustka
# Processing Record 22 of Set 11 | danville
# Processing Record 23 of Set 11 | doha
# Processing Record 24 of Set 11 | bolgar
# Processing Record 25 of Set 11 | sur
# Processing Record 26 of Set 11 | mananara
# Processing Record 27 of Set 11 | hualmay
# Processing Record 28 of Set 11 | nusaybin
# Processing Record 29 of Set 11 | ajdabiya
# Processing Record 30 of Set 11 | misratah
# Processing Record 31 of Set 11 | paita
# Processing Record 32 of Set 11 | gao
# Processing Record 33 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 34 of Set 11 | tarata
# Processing Record 35 of Set 11 | merthyr tydfil
# Processing Record 36 of Set 11 | saulkrasti
# Processing Record 37 of Set 11 | weligama
# Processing Record 38 of Set 11 | carauari
# Processing Record 39 of Set 11 | merrill
# Processing Record 40 of Set 11 | nyagan
# Processing Record 41 of Set 11 | wukari
# Processing Record 42 of Set 11 | buarcos
# Processing Record 43 of Set 11 | kadyy
# Processing Record 44 of Set 11 | bam
# Processing Record 45 of Set 11 | bezhanitsy
# Processing Record 46 of Set 11 | mombaca
# Processing Record 47 of Set 11 | saint anthony
# Processing Record 48 of Set 11 | mehamn
# Processing Record 49 of Set 11 | aksu
# Processing Record 50 of Set 11 | muisne
# Processing Record 1 of Set 12 | concordia
# Processing Record 2 of Set 12 | dakar
# Processing Record 3 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 4 of Set 12 | qasigiannguit
# Processing Record 5 of Set 12 | abu kamal
# Processing Record 6 of Set 12 | lapy
# Processing Record 7 of Set 12 | thunder bay
# Processing Record 8 of Set 12 | andenes
# Processing Record 9 of Set 12 | indiana
# Processing Record 10 of Set 12 | gemena
# Processing Record 11 of Set 12 | carikar
# City not found. Skipping...
# Processing Record 12 of Set 12 | plouzane
# Processing Record 13 of Set 12 | rigaud
# Processing Record 14 of Set 12 | curvelo
# Processing Record 15 of Set 12 | gubskaya
# Processing Record 16 of Set 12 | vila franca do campo
# Processing Record 17 of Set 12 | monrovia
# Processing Record 18 of Set 12 | batsfjord
# Processing Record 19 of Set 12 | puerto el triunfo
# Processing Record 20 of Set 12 | draguignan
# Processing Record 21 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 12 | mizdah
# Processing Record 23 of Set 12 | gogrial
# Processing Record 24 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 26 of Set 12 | uvinza
# Processing Record 27 of Set 12 | surt
# Processing Record 28 of Set 12 | limenaria
# Processing Record 29 of Set 12 | arkhangelsk
# Processing Record 30 of Set 12 | mizan teferi
# Processing Record 31 of Set 12 | kyshtovka
# Processing Record 32 of Set 12 | peniche
# Processing Record 33 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 12 | jeremie
# Processing Record 35 of Set 12 | santa cruz
# Processing Record 36 of Set 12 | kapoeta
# Processing Record 37 of Set 12 | scarborough
# Processing Record 38 of Set 12 | vadu pasii
# Processing Record 39 of Set 12 | el carmen de bolivar
# Processing Record 40 of Set 12 | tasgaon
# Processing Record 41 of Set 12 | marathon
# Processing Record 42 of Set 12 | samana
# Processing Record 43 of Set 12 | oranjemund
# Processing Record 44 of Set 12 | ibra
# Processing Record 45 of Set 12 | kati
# Processing Record 46 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 47 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 48 of Set 12 | pitimbu
# Processing Record 49 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 12 | gbadolite
# Processing Record 1 of Set 13 | cradock
# Processing Record 2 of Set 13 | mgandu
# Processing Record 3 of Set 13 | markivka
# Processing Record 4 of Set 13 | kortkeros
# Processing Record 5 of Set 13 | khomeynishahr
# City not found. Skipping...
# Processing Record 6 of Set 13 | botucatu
# Processing Record 7 of Set 13 | san francisco
# Processing Record 8 of Set 13 | constitucion
# Processing Record 9 of Set 13 | sao jose da coroa grande
# Processing Record 10 of Set 13 | grahamstown
# Processing Record 11 of Set 13 | bhitarwar
# Processing Record 12 of Set 13 | liwale
# Processing Record 13 of Set 13 | badulla
# Processing Record 14 of Set 13 | beisfjord
# Processing Record 15 of Set 13 | angoche
# Processing Record 16 of Set 13 | odlabari
# Processing Record 17 of Set 13 | sayyan
# Processing Record 18 of Set 13 | mutoko
# Processing Record 19 of Set 13 | kodar
# Processing Record 20 of Set 13 | bhopal
# Processing Record 21 of Set 13 | bandrele
# Processing Record 22 of Set 13 | valkeakoski
# Processing Record 23 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 24 of Set 13 | virginia beach
# Processing Record 25 of Set 13 | rio cuarto
# Processing Record 26 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 13 | mbinga
# Processing Record 28 of Set 13 | gilgil
# City not found. Skipping...
# Processing Record 29 of Set 13 | brekstad
# Processing Record 30 of Set 13 | carballo
# Processing Record 31 of Set 13 | gonzalez
# Processing Record 32 of Set 13 | malatya
# Processing Record 33 of Set 13 | leghorn
# City not found. Skipping...
# Processing Record 34 of Set 13 | thompson
# Processing Record 35 of Set 13 | indiaroba
# Processing Record 36 of Set 13 | toamasina
# Processing Record 37 of Set 13 | sao felix do xingu
# Processing Record 38 of Set 13 | mehran
# Processing Record 39 of Set 13 | general roca
# Processing Record 40 of Set 13 | klyuchi
# Processing Record 41 of Set 13 | kilinochchi
# Processing Record 42 of Set 13 | kumbo
# Processing Record 43 of Set 13 | batken
# Processing Record 44 of Set 13 | kinshasa
# Processing Record 45 of Set 13 | altay
# Processing Record 46 of Set 13 | jalu
# Processing Record 47 of Set 13 | sao miguel do araguaia
# Processing Record 48 of Set 13 | tuscaloosa
# Processing Record 49 of Set 13 | havelock
# Processing Record 50 of Set 13 | adre
# Processing Record 1 of Set 14 | iacu
# Processing Record 2 of Set 14 | rosita
# Processing Record 3 of Set 14 | santander
# Processing Record 4 of Set 14 | plettenberg bay
# Processing Record 5 of Set 14 | isiro
# Processing Record 6 of Set 14 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 7 of Set 14 | boa vista
# Processing Record 8 of Set 14 | dhrangadhra
# Processing Record 9 of Set 14 | itabira
# Processing Record 10 of Set 14 | bollnas
# Processing Record 11 of Set 14 | tumbi
# Processing Record 12 of Set 14 | remanso
# Processing Record 13 of Set 14 | lukulu
# Processing Record 14 of Set 14 | burlatskoye
# Processing Record 15 of Set 14 | gornopravdinsk
# Processing Record 16 of Set 14 | chengannur
# Processing Record 17 of Set 14 | letterkenny
# Processing Record 18 of Set 14 | morondava
# Processing Record 19 of Set 14 | meiganga
# Processing Record 20 of Set 14 | talara
# Processing Record 21 of Set 14 | abeche
# Processing Record 22 of Set 14 | treinta y tres
# Processing Record 23 of Set 14 | dospat
# Processing Record 24 of Set 14 | progreso
# Processing Record 25 of Set 14 | general pico
# Processing Record 26 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 14 | monaragala
# Processing Record 28 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 14 | icod de los vinos
# Processing Record 30 of Set 14 | ler
# Processing Record 31 of Set 14 | nizhniy odes
# Processing Record 32 of Set 14 | bay roberts
# Processing Record 33 of Set 14 | elizabeth city
# Processing Record 34 of Set 14 | calamar
# Processing Record 35 of Set 14 | the valley
# Processing Record 36 of Set 14 | dubki
# Processing Record 37 of Set 14 | eyl
# Processing Record 38 of Set 14 | eydhafushi
# Processing Record 39 of Set 14 | kargasok
# Processing Record 40 of Set 14 | buchanan
# Processing Record 41 of Set 14 | manbij
# Processing Record 42 of Set 14 | bosaso
# Processing Record 43 of Set 14 | streator
# Processing Record 44 of Set 14 | herat
# Processing Record 45 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 14 | saint-denis
# Processing Record 47 of Set 14 | taltal
# Processing Record 48 of Set 14 | viedma
# Processing Record 49 of Set 14 | potchefstroom
# Processing Record 50 of Set 14 | burgeo
# Processing Record 1 of Set 15 | hershey
# Processing Record 2 of Set 15 | malyye derbety
# Processing Record 3 of Set 15 | sendafa
# Processing Record 4 of Set 15 | suratgarh
# Processing Record 5 of Set 15 | shirvan
# Processing Record 6 of Set 15 | vytegra
# Processing Record 7 of Set 15 | tocopilla
# Processing Record 8 of Set 15 | berbera
# Processing Record 9 of Set 15 | koslan
# Processing Record 10 of Set 15 | kaniv
# Processing Record 11 of Set 15 | aragarcas
# Processing Record 12 of Set 15 | bethal
# Processing Record 13 of Set 15 | maicao
# Processing Record 14 of Set 15 | tarancon
# Processing Record 15 of Set 15 | kismayo
# Processing Record 16 of Set 15 | guanay
# Processing Record 17 of Set 15 | beni mazar
# Processing Record 18 of Set 15 | ongandjera
# Processing Record 19 of Set 15 | west bay
# Processing Record 20 of Set 15 | lekoni
# Processing Record 21 of Set 15 | hudiksvall
# Processing Record 22 of Set 15 | fomboni
# Processing Record 23 of Set 15 | sarahan
# Processing Record 24 of Set 15 | chalons-en-champagne
# Processing Record 25 of Set 15 | parfenyevo
# Processing Record 26 of Set 15 | culpeper
# Processing Record 27 of Set 15 | nahan
# Processing Record 28 of Set 15 | mayma
# Processing Record 29 of Set 15 | wum
# Processing Record 30 of Set 15 | yarim
# Processing Record 31 of Set 15 | nola
# Processing Record 32 of Set 15 | bikapur
# Processing Record 33 of Set 15 | papagaios
# Processing Record 34 of Set 15 | halifax
# Processing Record 35 of Set 15 | buraydah
# Processing Record 36 of Set 15 | skibbereen
# Processing Record 37 of Set 15 | aracaju
# Processing Record 38 of Set 15 | russkaya polyana
# Processing Record 39 of Set 15 | mabaruma
# Processing Record 40 of Set 15 | myhove
# Processing Record 41 of Set 15 | hyeres
# Processing Record 42 of Set 15 | tabuk
# Processing Record 43 of Set 15 | talant
# Processing Record 44 of Set 15 | berlin
# Processing Record 45 of Set 15 | kjollefjord
# Processing Record 46 of Set 15 | bull savanna
# Processing Record 47 of Set 15 | mitu
# Processing Record 48 of Set 15 | bertoua
# Processing Record 49 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 15 | stephenville
# Processing Record 1 of Set 16 | boca do acre
# Processing Record 2 of Set 16 | aksum
# Processing Record 3 of Set 16 | krasnogvardeyskoye
# Processing Record 4 of Set 16 | dabhol
# Processing Record 5 of Set 16 | matay
# Processing Record 6 of Set 16 | aden
# Processing Record 7 of Set 16 | raga
# Processing Record 8 of Set 16 | montevideo
# Processing Record 9 of Set 16 | voyvozh
# Processing Record 10 of Set 16 | nara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0             Kadhan  24.4810  68.9859     78.82        63           5
# 1          Cape Town -33.9258  18.4232     70.00        72           0
# 2             Castro -24.7911 -50.0119     71.64        84         100
# 3           Vallenar -28.5708 -70.7581     80.51        30           0
# 4  Sao Joao Da Barra -21.6403 -41.0511     86.00        66          20
# 5            Copiapo -27.3667 -70.3333     68.00        52           0
# 6              Tahta  26.7693  31.5021     66.20        27           0
# 7           Meulaboh   4.1363  96.1285     77.27        86          96
# 8          Upernavik  72.7868 -56.1549    -17.70        80          24
# 9         Vila Velha -20.3297 -40.2925     82.40        65          40
#
#    Wind Speed Country Current Description
# 0       14.00      PK           clear sky
# 1        6.91      ZA           clear sky
# 2        6.31      BR     overcast clouds
# 3        8.70      CL           clear sky
# 4        6.91      BR          few clouds
# 5       10.36      CL           clear sky
# 6       17.27      EG           clear sky
# 7        2.37      ID     overcast clouds
# 8        2.44      GL          few clouds
# 9        6.91      BR    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Kadhan      PK  24.4810   68.9859     78.82        63
# 1            Cape Town      ZA -33.9258   18.4232     70.00        72
# 2               Castro      BR -24.7911  -50.0119     71.64        84
# 3             Vallenar      CL -28.5708  -70.7581     80.51        30
# 4    Sao Joao Da Barra      BR -21.6403  -41.0511     86.00        66
# ..                 ...     ...      ...       ...       ...       ...
# 691               Aden      YE  12.7794   45.0367     80.74        61
# 692               Raga      SS   8.4596   25.6780     78.28        18
# 693         Montevideo      UY -34.8335  -56.1674     73.40        64
# 694            Voyvozh      RU  62.8920   54.9635     28.08        95
# 695               Nara      JP  34.6851  135.8049     57.99        91
#
#      Cloudiness  Wind Speed Current Description
# 0             5       14.00           clear sky
# 1             0        6.91           clear sky
# 2           100        6.31     overcast clouds
# 3             0        8.70           clear sky
# 4            20        6.91          few clouds
# ..          ...         ...                 ...
# 691           5        5.99           clear sky
# 692           5        4.12           clear sky
# 693          20        9.22          few clouds
# 694          99        6.29     overcast clouds
# 695          14        5.64          few clouds
#
# [696 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
